# %%
#!pip3 install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu117

# %%
import torch
x = torch.rand(5, 3)
print(x)
# Out:
# tensor([[0.6333, 0.8664, 0.0909],
#         [0.9609, 0.6350, 0.5383],
#         [0.9167, 0.9461, 0.1979],
#         [0.2380, 0.0145, 0.1895],
#         [0.0169, 0.6895, 0.3469]])

# %%
torch.cuda.is_available()
# Out:
# True

# %%
import tensorflow as tf

# %%
print(tf.reduce_sum(tf.random.normal([1000, 1000])))
# Out:
# tf.Tensor(-1569.6661, shape=(), dtype=float32)

# %%
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
print(tf.config.list_physical_devices())
# Out:
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU'), PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]

# %%
import nltk
import numpy as np
import matplotlib

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
from nltk.book import *

# %%
text9.concordance("monstrous")
# Out:
# Displaying 6 of 6 matches:
# warfish trees like some fierce and monstrous fruit . And this was strongest of
# ever thought of asking whether the monstrous man who almost filled and broke th
# ly to an infinite height above the monstrous men around him . For an instant ,
# ving the square black mob like one monstrous beetle . In the very strong sunlig
# ." Dr . Renard was a mild man with monstrous wealth ; his rooms were like the M
# efore one of them could move , the monstrous man had swung himself like some hu

# %%
text9.dispersion_plot(["monstrous", "humble","young", "silent","good", "two", "little"])

# %%
sorted(set(text9))
# Out:
# ['!',
#  '!"',
#  "!'",
#  '!--',
#  '"',
#  '"\'',
#  '"--',
#  '";',
#  "'",
#  "'--",
#  "'.",
#  '\'."',
#  "';",
#  "'?",
#  '\'?"',
#  '(',
#  ')',
#  '),',
#  ').',
#  ')."',
#  '*',
#  ',',
#  ',"',
#  ",'",
#  ',\'"',
#  '-',
#  '--',
#  '--"',
#  "--'",
#  '.',
#  '."',
#  '."\'',
#  ".'",
#  '.\'"',
#  '.--',
#  '1350',
#  '1908',
#  '217',
#  '45',
#  '7',
#  ':',
#  ':--',
#  ';',
#  '?',
#  '?"',
#  "?'",
#  '?)',
#  'A',
#  'ACCUSER',
#  'ACROSS',
#  'ANARCHY',
#  'AS',
#  'AT',
#  'About',
#  'Above',
#  'Absurd',
#  'Accepting',
#  'Acheron',
#  'Across',
#  'Acting',
#  'Adam',
#  'Admiral',
#  'Aesop',
#  'African',
#  'After',
#  'Afterwards',
#  'Again',
#  'Against',
#  'Ages',
#  'Ah',
#  'Albany',
#  'Albert',
#  'Alhambra',
#  'Alice',
#  'All',
#  'Ally',
#  'Almighty',
#  'Almost',
#  'Along',
#  'Alpine',
#  'Also',
#  'Am',
#  'America',
#  'American',
#  'An',
#  'Anarch',
#  'Anarchist',
#  'Anarchists',
#  'Anarchy',
#  'And',
#  'Anne',
#  'Another',
# ...

# %%
len(text9)
# Out:
# 69213

# %%
len(set(text9))
# Out:
# 6807

# %%
len(set(text9))/len(text9)*100
# Out:
# 9.83485761345412

# %%
text9[174]
# Out:
# 'foolish'

# %%
tokens = set([w.lower() for w in text9])

# %%
tokens = sorted(tokens)

# %%
tokens[-10:]
# Out:
# ['youthful',
#  'zare',
#  'zay',
#  'ze',
#  'zem',
#  'zmite',
#  'zoo',
#  'zoological',
#  'zso',
#  'zumpt']

# %%
fdist = FreqDist(text9)

# %%
fdist.most_common(50)
# Out:
# [(',', 3488),
#  ('the', 3291),
#  ('.', 2717),
#  ('a', 1713),
#  ('of', 1710),
#  ('and', 1568),
#  ('"', 1336),
#  ('to', 1045),
#  ('in', 888),
#  ('I', 885),
#  ('he', 858),
#  ('that', 841),
#  ('his', 765),
#  ('was', 716),
#  ('you', 580),
#  ('it', 565),
#  ('with', 544),
#  ('Syme', 515),
#  (',"', 507),
#  ('said', 507),
#  ("'", 496),
#  ('is', 462),
#  ('as', 456),
#  ('had', 427),
#  ('."', 391),
#  ('not', 355),
#  (';', 331),
#  ('The', 326),
#  ('at', 324),
#  ('-', 294),
#  ('on', 289),
#  ('but', 282),
#  ('for', 279),
#  ('him', 278),
#  ('all', 277),
#  ('man', 272),
#  ('He', 268),
#  ('like', 260),
#  ('be', 254),
#  ('this', 253),
#  ('have', 247),
#  ('are', 239),
#  ('they', 233),
#  ('an', 232),
#  ('s', 224),
#  ('were', 222),
#  ('out', 209),
#  ('?"', 203),
#  ('which', 198),
#  ('one', 187)]

# %%
V= set(text9)

# %%
long_words = [w for w in V if len(w) > 10]
sorted(long_words)
# Out:
# ['Aristocrats',
#  'Bannockburn',
#  'Chamberlain',
#  'Chamberlains',
#  'Christendom',
#  'Concealment',
#  'Consequently',
#  'Constitution',
#  'Elizabethan',
#  'Extraordinary',
#  'Gendarmerie',
#  'Godforsaken',
#  'Governments',
#  'Humanitarian',
#  'Impressionism',
#  'Mediterranean',
#  'Millionaires',
#  'Nevertheless',
#  'Nonconformists',
#  'PHILOSOPHERS',
#  'Refreshments',
#  'Renaissance',
#  'Robespierre',
#  'Sabbatarian',
#  'Superstition',
#  'Theoretically',
#  'UNACCOUNTABLE',
#  'Underground',
#  'Westminster',
#  'Witherspoon',
#  'abandonment',
#  'aberrations',
#  'abnegations',
#  'absentminded',
#  'abstractedly',
#  'abstraction',
#  'accidentally',
#  'accordingly',
#  'acknowledged',
#  'acquaintance',
#  'adventurers',
#  'advertisement',
#  'alphabetical',
#  'alternative',
#  'ambassadors',
#  'anonymously',
#  'anticipation',
#  'apologetically',
#  'appearances',
#  'application',
#  'apprehensive',
#  'approaching',
#  'appropriate',
# ...

# %%
sorted(w for w in set(text9) if len(w) > 7 and fdist[w] > 7)
# Out:
# ['Christians',
#  'Inspector',
#  'Leicester',
#  'President',
#  'Professor',
#  'Ratcliffe',
#  'Secretary',
#  'Thursday',
#  'Victoria',
#  'Witherspoon',
#  'abruptly',
#  'accident',
#  'adventures',
#  'afterwards',
#  'anarchist',
#  'anarchists',
#  'answered',
#  'anything',
#  'beautiful',
#  'breakfast',
#  'breaking',
#  'business',
#  'carriages',
#  'certainly',
#  'chairman',
#  'champagne',
#  'continued',
#  'contrast',
#  'conversation',
#  'criminal',
#  'curiosity',
#  'dangerous',
#  'darkness',
#  'detective',
#  'distance',
#  'election',
#  'elephant',
#  'enormous',
#  'especially',
#  'everything',
#  'extraordinary',
#  'followed',
#  'forehead',
#  'frightful',
#  'gentleman',
#  'gentlemen',
#  'gradually',
#  'horrible',
#  'humanity',
#  'impression',
#  'innkeeper',
#  'innocent',
#  'intellectual',
#  'laughing',
#  'laughter',
#  'nonsense',
#  'ordinary',
#  'original',
#  'paralytic',
#  'particular',
#  'passionate',
#  'pleasure',
# ...
